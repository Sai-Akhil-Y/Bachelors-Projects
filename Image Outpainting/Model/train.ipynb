# %%
# import shutil
# shutil.rmtree('sample_data', ignore_errors=True)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install html4vision
# Out:
# Requirement already satisfied: html4vision in /usr/local/lib/python3.7/dist-packages (0.4.2)
# Requirement already satisfied: dominate in /usr/local/lib/python3.7/dist-packages (from html4vision) (2.6.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from html4vision) (7.1.2)
# Requirement already satisfied: Flask in /usr/local/lib/python3.7/dist-packages (from html4vision) (1.1.2)
# Requirement already satisfied: click>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask->html4vision) (7.1.2)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask->html4vision) (1.1.0)
# Requirement already satisfied: Jinja2>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask->html4vision) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask->html4vision) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2>=2.10.1->Flask->html4vision) (1.1.1)

# %%
import sys
sys.path.append('/content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/')

# %%
import torch
from outpainting import *

print("PyTorch version: ", torch.__version__)
print("Torchvision version: ", torchvision.__version__)

# Define paths
model_save_path = '/content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_models'
html_save_path = '/content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html'
train_dir = '/content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/cat2dog/trainA'
val_dir = '/content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/cat2dog/valA'
test_dir = '/content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/cat2dog/testA'

# Define datasets & transforms
my_tf = transforms.Compose([
        transforms.Resize(output_size),
        transforms.CenterCrop(output_size),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor()])
batch_size = 4
train_data = CEImageDataset(train_dir, my_tf, output_size, input_size, outpaint=True)
val_data = CEImageDataset(val_dir, my_tf, output_size, input_size, outpaint=True)
test_data = CEImageDataset(test_dir, my_tf, output_size, input_size, outpaint=True)
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True, num_workers=1)
val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=True, num_workers=1)
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=True, num_workers=1)
print('train:', len(train_data), 'val:', len(val_data), 'test:', len(test_data))

# Define model & device
device = torch.device('cuda:0')
# device = torch.device('cpu')
G_net = CEGenerator(extra_upsample=True)
D_net = CEDiscriminator()
G_net.apply(weights_init_normal)
D_net.apply(weights_init_normal)
# G_net = nn.DataParallel(G_net)
# D_net = nn.DataParallel(D_net)
G_net.to(device)
D_net.to(device)
print('device:', device)

# Define losses
criterion_pxl = nn.L1Loss()
criterion_D = nn.MSELoss()
optimizer_G = optim.Adam(G_net.parameters(), lr=3e-4, betas=(0.5, 0.999))
optimizer_D = optim.Adam(D_net.parameters(), lr=3e-4, betas=(0.5, 0.999))
criterion_pxl.to(device)
criterion_D.to(device)

# Start training
data_loaders = {'train': train_loader, 'val': val_loader, 'test': test_loader} # NOTE: test is evidently not used by the train method
n_epochs = 150
adv_weight = [0.001, 0.005, 0.015, 0.040] # corresponds to epochs 1-10, 10-30, 30-60, 60-onwards
hist_loss = train_CE(G_net, D_net, device, criterion_pxl, criterion_D, optimizer_G, optimizer_D,
                      data_loaders, model_save_path, html_save_path, n_epochs=n_epochs, outpaint=True, adv_weight=adv_weight)

# Save loss history and final generator
pickle.dump(hist_loss, open('hist_loss.p', 'wb'))
torch.save(G_net.state_dict(), 'generator_final.pt')
# Out:
# PyTorch version:  1.8.1+cu101
# Torchvision version:  0.9.1+cu101
# train: 591 val: 180 test: 100
# device: cuda:0
# Batch 1/148  loss_pxl 0.6134  loss_adv 1.3501  loss_D 1.0640
# Batch 2/148  loss_pxl 0.5709  loss_adv 9.8089  loss_D 7.1726
# Batch 4/148  loss_pxl 0.6904  loss_adv 1.9788  loss_D 1.3428
# Batch 8/148  loss_pxl 0.4719  loss_adv 0.5312  loss_D 0.2052
# Batch 16/148  loss_pxl 0.2578  loss_adv 0.5994  loss_D 0.2364
# Batch 32/148  loss_pxl 0.1645  loss_adv 0.5948  loss_D 0.1513
# Batch 64/148  loss_pxl 0.1789  loss_adv 0.9968  loss_D 0.1242
# Batch 128/148  loss_pxl 0.1254  loss_adv 0.7714  loss_D 0.0929
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/0/index.html
# Epoch 1/150  train  loss_pxl 0.1959  loss_adv 0.9171  loss_D 0.2258
# Epoch 1/150  val  loss_pxl 0.1945  loss_adv 1.2251  loss_D 0.1505
#
# Batch 1/148  loss_pxl 0.1761  loss_adv 1.1973  loss_D 0.1597
# Batch 2/148  loss_pxl 0.1930  loss_adv 1.2238  loss_D 0.0976
# Batch 4/148  loss_pxl 0.1531  loss_adv 0.7841  loss_D 0.0733
# Batch 8/148  loss_pxl 0.1367  loss_adv 1.0161  loss_D 0.3377
# Batch 16/148  loss_pxl 0.1112  loss_adv 0.6354  loss_D 0.3788
# Batch 32/148  loss_pxl 0.1913  loss_adv 0.2201  loss_D 0.2307
# Batch 64/148  loss_pxl 0.1658  loss_adv 0.5877  loss_D 0.0726
# Batch 128/148  loss_pxl 0.2052  loss_adv 0.9330  loss_D 0.0256
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/1/index.html
# Epoch 2/150  train  loss_pxl 0.1463  loss_adv 0.7857  loss_D 0.2332
# Epoch 2/150  val  loss_pxl 0.1729  loss_adv 0.7632  loss_D 0.0382
#
# Batch 1/148  loss_pxl 0.1458  loss_adv 0.9413  loss_D 0.0244
# Batch 2/148  loss_pxl 0.1269  loss_adv 0.8502  loss_D 0.0447
# Batch 4/148  loss_pxl 0.1534  loss_adv 0.9917  loss_D 0.0530
# Batch 8/148  loss_pxl 0.1617  loss_adv 1.0834  loss_D 0.1833
# Batch 16/148  loss_pxl 0.1452  loss_adv 0.9810  loss_D 0.0237
# Batch 32/148  loss_pxl 0.1417  loss_adv 1.0307  loss_D 0.0385
# Batch 64/148  loss_pxl 0.1484  loss_adv 1.1681  loss_D 0.0428
# Batch 128/148  loss_pxl 0.1209  loss_adv 0.9341  loss_D 0.0240
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/2/index.html
# Epoch 3/150  train  loss_pxl 0.1386  loss_adv 0.9087  loss_D 0.0368
# Epoch 3/150  val  loss_pxl 0.1266  loss_adv 1.0746  loss_D 0.0338
#
# Batch 1/148  loss_pxl 0.0964  loss_adv 1.0495  loss_D 0.0307
# Batch 2/148  loss_pxl 0.1241  loss_adv 0.9343  loss_D 0.0686
# Batch 4/148  loss_pxl 0.1400  loss_adv 1.0418  loss_D 0.0696
# Batch 8/148  loss_pxl 0.1115  loss_adv 0.5142  loss_D 0.3971
# Batch 16/148  loss_pxl 0.1414  loss_adv 0.5815  loss_D 0.0738
# Batch 32/148  loss_pxl 0.1439  loss_adv 0.8264  loss_D 0.0179
# Batch 64/148  loss_pxl 0.1351  loss_adv 1.0893  loss_D 0.0181
# Batch 128/148  loss_pxl 0.1120  loss_adv 0.7324  loss_D 0.0515
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/3/index.html
# Epoch 4/150  train  loss_pxl 0.1341  loss_adv 0.8723  loss_D 0.0705
# Epoch 4/150  val  loss_pxl 0.1496  loss_adv 0.5413  loss_D 0.0883
#
# Batch 1/148  loss_pxl 0.1308  loss_adv 0.6494  loss_D 0.0522
# Batch 2/148  loss_pxl 0.1095  loss_adv 0.9384  loss_D 0.0587
# Batch 4/148  loss_pxl 0.1330  loss_adv 0.8394  loss_D 0.0266
# Batch 8/148  loss_pxl 0.1208  loss_adv 0.9610  loss_D 0.0407
# Batch 16/148  loss_pxl 0.1378  loss_adv 0.9975  loss_D 0.0476
# Batch 32/148  loss_pxl 0.1685  loss_adv 0.9053  loss_D 0.0232
# Batch 64/148  loss_pxl 0.0970  loss_adv 0.9415  loss_D 0.0127
# Batch 128/148  loss_pxl 0.1284  loss_adv 1.1106  loss_D 0.0119
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/4/index.html
# Epoch 5/150  train  loss_pxl 0.1286  loss_adv 0.9223  loss_D 0.0280
# Epoch 5/150  val  loss_pxl 0.1265  loss_adv 0.8355  loss_D 0.0190
#
# Batch 1/148  loss_pxl 0.1439  loss_adv 0.9691  loss_D 0.0104
# Batch 2/148  loss_pxl 0.1369  loss_adv 0.7307  loss_D 0.0304
# Batch 4/148  loss_pxl 0.1270  loss_adv 0.7964  loss_D 0.0303
# Batch 8/148  loss_pxl 0.0993  loss_adv 1.2522  loss_D 0.0272
# Batch 16/148  loss_pxl 0.1411  loss_adv 0.9638  loss_D 0.0147
# Batch 32/148  loss_pxl 0.1171  loss_adv 0.8920  loss_D 0.0295
# Batch 64/148  loss_pxl 0.1338  loss_adv 1.0008  loss_D 0.0240
# Batch 128/148  loss_pxl 0.1145  loss_adv 1.0558  loss_D 0.0361
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/5/index.html
# Epoch 6/150  train  loss_pxl 0.1267  loss_adv 0.9516  loss_D 0.0259
# Epoch 6/150  val  loss_pxl 0.1274  loss_adv 1.0953  loss_D 0.0137
#
# Batch 1/148  loss_pxl 0.1365  loss_adv 1.1100  loss_D 0.0118
# Batch 2/148  loss_pxl 0.1228  loss_adv 0.9779  loss_D 0.0410
# Batch 4/148  loss_pxl 0.0929  loss_adv 1.2074  loss_D 0.0375
# Batch 8/148  loss_pxl 0.1234  loss_adv 0.5447  loss_D 0.0592
# Batch 16/148  loss_pxl 0.1098  loss_adv 0.8948  loss_D 0.0112
# Batch 32/148  loss_pxl 0.1519  loss_adv 0.7764  loss_D 0.0276
# Batch 64/148  loss_pxl 0.1391  loss_adv 0.8764  loss_D 0.0285
# Batch 128/148  loss_pxl 0.1114  loss_adv 0.9317  loss_D 0.0167
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/6/index.html
# Epoch 7/150  train  loss_pxl 0.1254  loss_adv 0.9442  loss_D 0.0300
# Epoch 7/150  val  loss_pxl 0.1188  loss_adv 1.0041  loss_D 0.0128
#
# Batch 1/148  loss_pxl 0.1380  loss_adv 1.0424  loss_D 0.0078
# Batch 2/148  loss_pxl 0.1486  loss_adv 0.9752  loss_D 0.0065
# Batch 4/148  loss_pxl 0.0920  loss_adv 0.9941  loss_D 0.0217
# Batch 8/148  loss_pxl 0.1250  loss_adv 0.9792  loss_D 0.0186
# Batch 16/148  loss_pxl 0.1164  loss_adv 0.8408  loss_D 0.0144
# Batch 32/148  loss_pxl 0.1197  loss_adv 0.6623  loss_D 0.0291
# Batch 64/148  loss_pxl 0.1296  loss_adv 0.9640  loss_D 0.0265
# Batch 128/148  loss_pxl 0.1365  loss_adv 0.8431  loss_D 0.0174
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/7/index.html
# Epoch 8/150  train  loss_pxl 0.1213  loss_adv 0.9277  loss_D 0.0416
# Epoch 8/150  val  loss_pxl 0.1327  loss_adv 1.1374  loss_D 0.0192
#
# Batch 1/148  loss_pxl 0.1077  loss_adv 1.0283  loss_D 0.0148
# Batch 2/148  loss_pxl 0.1472  loss_adv 1.0263  loss_D 0.0091
# Batch 4/148  loss_pxl 0.1700  loss_adv 0.9337  loss_D 0.0138
# Batch 8/148  loss_pxl 0.1191  loss_adv 1.1197  loss_D 0.0112
# Batch 16/148  loss_pxl 0.1050  loss_adv 0.8996  loss_D 0.0142
# Batch 32/148  loss_pxl 0.1136  loss_adv 0.9661  loss_D 0.0164
# Batch 64/148  loss_pxl 0.1290  loss_adv 0.9985  loss_D 0.1287
# Batch 128/148  loss_pxl 0.1194  loss_adv 0.4839  loss_D 0.0620
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/8/index.html
# Epoch 9/150  train  loss_pxl 0.1208  loss_adv 0.9445  loss_D 0.0361
# Epoch 9/150  val  loss_pxl 0.1229  loss_adv 0.5382  loss_D 0.0585
#
# Batch 1/148  loss_pxl 0.0782  loss_adv 0.7519  loss_D 0.0192
# Batch 2/148  loss_pxl 0.0906  loss_adv 1.1063  loss_D 0.0130
# Batch 4/148  loss_pxl 0.0978  loss_adv 0.9682  loss_D 0.0097
# Batch 8/148  loss_pxl 0.1096  loss_adv 0.8768  loss_D 0.0112
# Batch 16/148  loss_pxl 0.0948  loss_adv 0.8330  loss_D 0.0301
# Batch 32/148  loss_pxl 0.1104  loss_adv 0.9310  loss_D 0.0141
# Batch 64/148  loss_pxl 0.1027  loss_adv 0.8629  loss_D 0.0144
# Batch 128/148  loss_pxl 0.1155  loss_adv 1.2633  loss_D 0.0895
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/9/index.html
# Epoch 10/150  train  loss_pxl 0.1165  loss_adv 0.9359  loss_D 0.0318
# Epoch 10/150  val  loss_pxl 0.1308  loss_adv 0.8312  loss_D 0.0639
#
# Batch 1/148  loss_pxl 0.1080  loss_adv 0.8068  loss_D 0.0649
# Batch 2/148  loss_pxl 0.1034  loss_adv 1.2122  loss_D 0.0485
# Batch 4/148  loss_pxl 0.1287  loss_adv 1.0636  loss_D 0.0475
# Batch 8/148  loss_pxl 0.1165  loss_adv 1.2657  loss_D 0.1582
# Batch 16/148  loss_pxl 0.1352  loss_adv 0.6155  loss_D 0.0856
# Batch 32/148  loss_pxl 0.1172  loss_adv 0.7328  loss_D 0.0676
# Batch 64/148  loss_pxl 0.1633  loss_adv 1.1061  loss_D 0.2195
# Batch 128/148  loss_pxl 0.1067  loss_adv 1.2445  loss_D 0.1885
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/10/index.html
# Epoch 11/150  train  loss_pxl 0.1164  loss_adv 0.7585  loss_D 0.1076
# Epoch 11/150  val  loss_pxl 0.1207  loss_adv 0.6808  loss_D 0.0728
#
# Batch 1/148  loss_pxl 0.1074  loss_adv 0.8318  loss_D 0.1094
# Batch 2/148  loss_pxl 0.1500  loss_adv 0.6573  loss_D 0.0584
# Batch 4/148  loss_pxl 0.0961  loss_adv 0.8234  loss_D 0.0271
# Batch 8/148  loss_pxl 0.1032  loss_adv 0.8787  loss_D 0.1534
# Batch 16/148  loss_pxl 0.1056  loss_adv 0.5002  loss_D 0.0854
# Batch 32/148  loss_pxl 0.1190  loss_adv 0.6844  loss_D 0.0918
# Batch 64/148  loss_pxl 0.0948  loss_adv 1.1337  loss_D 0.0657
# Batch 128/148  loss_pxl 0.0987  loss_adv 0.9394  loss_D 0.0611
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/11/index.html
# Epoch 12/150  train  loss_pxl 0.1134  loss_adv 0.7959  loss_D 0.0853
# Epoch 12/150  val  loss_pxl 0.1236  loss_adv 0.8979  loss_D 0.0420
#
# Batch 1/148  loss_pxl 0.1394  loss_adv 0.9258  loss_D 0.0518
# Batch 2/148  loss_pxl 0.1205  loss_adv 0.7200  loss_D 0.0723
# Batch 4/148  loss_pxl 0.0894  loss_adv 1.4267  loss_D 0.1149
# Batch 8/148  loss_pxl 0.1320  loss_adv 1.4710  loss_D 0.0974
# Batch 16/148  loss_pxl 0.0885  loss_adv 0.8607  loss_D 0.0675
# Batch 32/148  loss_pxl 0.1083  loss_adv 0.9782  loss_D 0.0379
# Batch 64/148  loss_pxl 0.1161  loss_adv 0.4962  loss_D 0.0908
# Batch 128/148  loss_pxl 0.1049  loss_adv 0.8571  loss_D 0.0676
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/12/index.html
# Epoch 13/150  train  loss_pxl 0.1139  loss_adv 0.8202  loss_D 0.0758
# Epoch 13/150  val  loss_pxl 0.1442  loss_adv 0.6109  loss_D 0.0570
#
# Batch 1/148  loss_pxl 0.1311  loss_adv 0.5859  loss_D 0.0443
# Batch 2/148  loss_pxl 0.0925  loss_adv 1.0341  loss_D 0.0218
# Batch 4/148  loss_pxl 0.0981  loss_adv 0.5224  loss_D 0.0841
# Batch 8/148  loss_pxl 0.1211  loss_adv 0.6698  loss_D 0.0444
# Batch 16/148  loss_pxl 0.0962  loss_adv 0.5274  loss_D 0.0612
# Batch 32/148  loss_pxl 0.1114  loss_adv 0.6921  loss_D 0.0462
# Batch 64/148  loss_pxl 0.1012  loss_adv 0.3878  loss_D 0.1146
# Batch 128/148  loss_pxl 0.1231  loss_adv 1.2957  loss_D 0.0316
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/13/index.html
# Epoch 14/150  train  loss_pxl 0.1113  loss_adv 0.7972  loss_D 0.1014
# Epoch 14/150  val  loss_pxl 0.1110  loss_adv 1.0865  loss_D 0.0682
#
# Batch 1/148  loss_pxl 0.1493  loss_adv 1.3278  loss_D 0.1757
# Batch 2/148  loss_pxl 0.1134  loss_adv 0.3074  loss_D 0.1525
# Batch 4/148  loss_pxl 0.0969  loss_adv 0.5271  loss_D 0.1097
# Batch 8/148  loss_pxl 0.1095  loss_adv 0.7208  loss_D 0.0508
# Batch 16/148  loss_pxl 0.1229  loss_adv 1.1426  loss_D 0.0801
# Batch 32/148  loss_pxl 0.1063  loss_adv 0.5283  loss_D 0.1057
# Batch 64/148  loss_pxl 0.0988  loss_adv 1.0641  loss_D 0.0727
# Batch 128/148  loss_pxl 0.1235  loss_adv 0.2518  loss_D 0.1880
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/14/index.html
# Epoch 15/150  train  loss_pxl 0.1101  loss_adv 0.7789  loss_D 0.0850
# Epoch 15/150  val  loss_pxl 0.1182  loss_adv 0.5051  loss_D 0.0822
#
# Batch 1/148  loss_pxl 0.1484  loss_adv 0.5048  loss_D 0.0681
# Batch 2/148  loss_pxl 0.1272  loss_adv 0.7618  loss_D 0.0367
# Batch 4/148  loss_pxl 0.1116  loss_adv 0.7846  loss_D 0.1163
# Batch 8/148  loss_pxl 0.1120  loss_adv 1.0401  loss_D 0.0625
# Batch 16/148  loss_pxl 0.0968  loss_adv 0.7504  loss_D 0.0631
# Batch 32/148  loss_pxl 0.0967  loss_adv 0.1510  loss_D 0.2698
# Batch 64/148  loss_pxl 0.1310  loss_adv 0.8106  loss_D 0.0419
# Batch 128/148  loss_pxl 0.1178  loss_adv 0.3009  loss_D 0.1478
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/15/index.html
# Epoch 16/150  train  loss_pxl 0.1098  loss_adv 0.7591  loss_D 0.0897
# Epoch 16/150  val  loss_pxl 0.1208  loss_adv 1.0215  loss_D 0.0603
#
# Batch 1/148  loss_pxl 0.1594  loss_adv 0.8470  loss_D 0.0462
# Batch 2/148  loss_pxl 0.0957  loss_adv 1.0224  loss_D 0.0915
# Batch 4/148  loss_pxl 0.1396  loss_adv 0.5293  loss_D 0.0653
# Batch 8/148  loss_pxl 0.1408  loss_adv 0.8574  loss_D 0.0278
# Batch 16/148  loss_pxl 0.1331  loss_adv 0.1609  loss_D 0.2670
# Batch 32/148  loss_pxl 0.0845  loss_adv 0.6464  loss_D 0.0999
# Batch 64/148  loss_pxl 0.0970  loss_adv 0.9721  loss_D 0.0532
# Batch 128/148  loss_pxl 0.0936  loss_adv 0.9886  loss_D 0.0679
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/16/index.html
# Epoch 17/150  train  loss_pxl 0.1100  loss_adv 0.7602  loss_D 0.0976
# Epoch 17/150  val  loss_pxl 0.1127  loss_adv 0.7685  loss_D 0.0585
#
# Batch 1/148  loss_pxl 0.1122  loss_adv 0.5725  loss_D 0.0622
# Batch 2/148  loss_pxl 0.1150  loss_adv 1.3814  loss_D 0.1802
# Batch 4/148  loss_pxl 0.0879  loss_adv 0.4468  loss_D 0.1207
# Batch 8/148  loss_pxl 0.1459  loss_adv 0.9313  loss_D 0.0721
# Batch 16/148  loss_pxl 0.0990  loss_adv 1.1797  loss_D 0.2218
# Batch 32/148  loss_pxl 0.1000  loss_adv 1.1847  loss_D 0.0521
# Batch 64/148  loss_pxl 0.1074  loss_adv 0.5065  loss_D 0.0900
# Batch 128/148  loss_pxl 0.0888  loss_adv 0.7709  loss_D 0.1263
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/17/index.html
# Epoch 18/150  train  loss_pxl 0.1096  loss_adv 0.7461  loss_D 0.0932
# Epoch 18/150  val  loss_pxl 0.1090  loss_adv 0.4648  loss_D 0.1166
#
# Batch 1/148  loss_pxl 0.1049  loss_adv 0.6136  loss_D 0.0692
# Batch 2/148  loss_pxl 0.0905  loss_adv 0.7824  loss_D 0.0613
# Batch 4/148  loss_pxl 0.1090  loss_adv 0.6558  loss_D 0.0582
# Batch 8/148  loss_pxl 0.0864  loss_adv 0.7960  loss_D 0.0661
# Batch 16/148  loss_pxl 0.1053  loss_adv 0.8956  loss_D 0.3115
# Batch 32/148  loss_pxl 0.1231  loss_adv 0.4656  loss_D 0.0956
# Batch 64/148  loss_pxl 0.1212  loss_adv 0.3583  loss_D 0.1179
# Batch 128/148  loss_pxl 0.1154  loss_adv 0.3185  loss_D 0.1701
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/18/index.html
# Epoch 19/150  train  loss_pxl 0.1034  loss_adv 0.7002  loss_D 0.1181
# Epoch 19/150  val  loss_pxl 0.1102  loss_adv 0.4831  loss_D 0.0930
#
# Batch 1/148  loss_pxl 0.1137  loss_adv 0.4633  loss_D 0.0770
# Batch 2/148  loss_pxl 0.0935  loss_adv 0.7866  loss_D 0.0409
# Batch 4/148  loss_pxl 0.1240  loss_adv 0.6486  loss_D 0.0706
# Batch 8/148  loss_pxl 0.1106  loss_adv 0.4544  loss_D 0.1044
# Batch 16/148  loss_pxl 0.0952  loss_adv 0.3671  loss_D 0.1664
# Batch 32/148  loss_pxl 0.1055  loss_adv 0.9680  loss_D 0.0554
# Batch 64/148  loss_pxl 0.1313  loss_adv 0.6079  loss_D 0.0808
# Batch 128/148  loss_pxl 0.0798  loss_adv 0.5936  loss_D 0.1057
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/19/index.html
# Epoch 20/150  train  loss_pxl 0.1028  loss_adv 0.6857  loss_D 0.1161
# Epoch 20/150  val  loss_pxl 0.1062  loss_adv 0.5587  loss_D 0.0914
#
# Batch 1/148  loss_pxl 0.0869  loss_adv 0.5040  loss_D 0.1155
# Batch 2/148  loss_pxl 0.1023  loss_adv 0.4301  loss_D 0.1590
# Batch 4/148  loss_pxl 0.0994  loss_adv 0.6676  loss_D 0.1023
# Batch 8/148  loss_pxl 0.1204  loss_adv 0.9909  loss_D 0.1034
# Batch 16/148  loss_pxl 0.0884  loss_adv 0.7383  loss_D 0.0482
# Batch 32/148  loss_pxl 0.0978  loss_adv 0.8642  loss_D 0.1222
# Batch 64/148  loss_pxl 0.0909  loss_adv 1.0717  loss_D 0.1137
# Batch 128/148  loss_pxl 0.0944  loss_adv 0.4232  loss_D 0.1185
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/20/index.html
# Epoch 21/150  train  loss_pxl 0.1001  loss_adv 0.6795  loss_D 0.1156
# Epoch 21/150  val  loss_pxl 0.1142  loss_adv 0.7231  loss_D 0.0910
#
# Batch 1/148  loss_pxl 0.0895  loss_adv 0.6831  loss_D 0.1523
# Batch 2/148  loss_pxl 0.0887  loss_adv 0.3029  loss_D 0.2067
# Batch 4/148  loss_pxl 0.0993  loss_adv 1.0662  loss_D 0.2067
# Batch 8/148  loss_pxl 0.0875  loss_adv 0.7168  loss_D 0.0404
# Batch 16/148  loss_pxl 0.1086  loss_adv 0.8283  loss_D 0.0498
# Batch 32/148  loss_pxl 0.0820  loss_adv 0.9312  loss_D 0.0561
# Batch 64/148  loss_pxl 0.1170  loss_adv 0.6289  loss_D 0.0466
# Batch 128/148  loss_pxl 0.1214  loss_adv 0.6128  loss_D 0.1117
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/21/index.html
# Epoch 22/150  train  loss_pxl 0.0999  loss_adv 0.6799  loss_D 0.1152
# Epoch 22/150  val  loss_pxl 0.1220  loss_adv 0.1289  loss_D 0.3114
#
# Batch 1/148  loss_pxl 0.1031  loss_adv 0.2133  loss_D 0.2596
# Batch 2/148  loss_pxl 0.0965  loss_adv 1.0343  loss_D 0.1921
# Batch 4/148  loss_pxl 0.0929  loss_adv 0.7604  loss_D 0.1363
# Batch 8/148  loss_pxl 0.0910  loss_adv 0.9235  loss_D 0.1226
# Batch 16/148  loss_pxl 0.1186  loss_adv 0.7718  loss_D 0.0463
# Batch 32/148  loss_pxl 0.1125  loss_adv 0.4454  loss_D 0.0868
# Batch 64/148  loss_pxl 0.0808  loss_adv 0.9339  loss_D 0.1509
# Batch 128/148  loss_pxl 0.1031  loss_adv 0.8884  loss_D 0.0649
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/22/index.html
# Epoch 23/150  train  loss_pxl 0.0980  loss_adv 0.6705  loss_D 0.1158
# Epoch 23/150  val  loss_pxl 0.1165  loss_adv 0.5338  loss_D 0.1169
#
# Batch 1/148  loss_pxl 0.1191  loss_adv 0.5826  loss_D 0.1104
# Batch 2/148  loss_pxl 0.0788  loss_adv 0.7311  loss_D 0.0876
# Batch 4/148  loss_pxl 0.0938  loss_adv 0.9123  loss_D 0.1225
# Batch 8/148  loss_pxl 0.1144  loss_adv 0.3845  loss_D 0.1387
# Batch 16/148  loss_pxl 0.1073  loss_adv 0.7697  loss_D 0.1154
# Batch 32/148  loss_pxl 0.1096  loss_adv 0.8691  loss_D 0.0444
# Batch 64/148  loss_pxl 0.1135  loss_adv 0.7407  loss_D 0.0395
# Batch 128/148  loss_pxl 0.1110  loss_adv 0.6869  loss_D 0.0863
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/23/index.html
# Epoch 24/150  train  loss_pxl 0.0974  loss_adv 0.6752  loss_D 0.1238
# Epoch 24/150  val  loss_pxl 0.1105  loss_adv 0.8177  loss_D 0.0888
#
# Batch 1/148  loss_pxl 0.0986  loss_adv 0.7715  loss_D 0.0787
# Batch 2/148  loss_pxl 0.0909  loss_adv 0.6472  loss_D 0.0935
# Batch 4/148  loss_pxl 0.0635  loss_adv 0.7825  loss_D 0.1470
# Batch 8/148  loss_pxl 0.0888  loss_adv 0.3830  loss_D 0.1027
# Batch 16/148  loss_pxl 0.1004  loss_adv 0.8854  loss_D 0.1030
# Batch 32/148  loss_pxl 0.0800  loss_adv 0.4144  loss_D 0.1725
# Batch 64/148  loss_pxl 0.1158  loss_adv 0.9088  loss_D 0.0961
# Batch 128/148  loss_pxl 0.0799  loss_adv 0.3667  loss_D 0.1340
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/24/index.html
# Epoch 25/150  train  loss_pxl 0.0959  loss_adv 0.6688  loss_D 0.1149
# Epoch 25/150  val  loss_pxl 0.1113  loss_adv 0.5827  loss_D 0.0838
#
# Batch 1/148  loss_pxl 0.0994  loss_adv 0.5934  loss_D 0.1095
# Batch 2/148  loss_pxl 0.0859  loss_adv 0.5601  loss_D 0.0622
# Batch 4/148  loss_pxl 0.0893  loss_adv 0.9499  loss_D 0.1525
# Batch 8/148  loss_pxl 0.1454  loss_adv 0.5601  loss_D 0.0947
# Batch 16/148  loss_pxl 0.0826  loss_adv 0.6479  loss_D 0.0770
# Batch 32/148  loss_pxl 0.0900  loss_adv 0.7333  loss_D 0.0971
# Batch 64/148  loss_pxl 0.0643  loss_adv 0.7601  loss_D 0.1949
# Batch 128/148  loss_pxl 0.0749  loss_adv 0.6689  loss_D 0.0880
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/25/index.html
# Epoch 26/150  train  loss_pxl 0.0954  loss_adv 0.6740  loss_D 0.1130
# Epoch 26/150  val  loss_pxl 0.1062  loss_adv 1.0194  loss_D 0.1124
#
# Batch 1/148  loss_pxl 0.1011  loss_adv 1.0409  loss_D 0.1470
# Batch 2/148  loss_pxl 0.0835  loss_adv 0.6535  loss_D 0.1120
# Batch 4/148  loss_pxl 0.0834  loss_adv 0.8007  loss_D 0.0909
# Batch 8/148  loss_pxl 0.0675  loss_adv 0.8477  loss_D 0.0858
# Batch 16/148  loss_pxl 0.0906  loss_adv 0.7090  loss_D 0.1641
# Batch 32/148  loss_pxl 0.1001  loss_adv 0.8269  loss_D 0.1208
# Batch 64/148  loss_pxl 0.0776  loss_adv 0.6173  loss_D 0.0999
# Batch 128/148  loss_pxl 0.1079  loss_adv 0.7583  loss_D 0.0439
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/26/index.html
# Epoch 27/150  train  loss_pxl 0.0939  loss_adv 0.6751  loss_D 0.1161
# Epoch 27/150  val  loss_pxl 0.1131  loss_adv 1.1052  loss_D 0.1356
#
# Batch 1/148  loss_pxl 0.0689  loss_adv 1.2773  loss_D 0.3335
# Batch 2/148  loss_pxl 0.0741  loss_adv 0.1379  loss_D 0.3115
# Batch 4/148  loss_pxl 0.1004  loss_adv 1.1037  loss_D 0.0737
# Batch 8/148  loss_pxl 0.0769  loss_adv 0.4017  loss_D 0.2085
# Batch 16/148  loss_pxl 0.1046  loss_adv 0.3771  loss_D 0.1420
# Batch 32/148  loss_pxl 0.0865  loss_adv 0.7524  loss_D 0.1474
# Batch 64/148  loss_pxl 0.1004  loss_adv 0.4722  loss_D 0.1317
# Batch 128/148  loss_pxl 0.0953  loss_adv 0.4996  loss_D 0.0695
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/27/index.html
# Epoch 28/150  train  loss_pxl 0.0928  loss_adv 0.6751  loss_D 0.1137
# Epoch 28/150  val  loss_pxl 0.1047  loss_adv 0.6448  loss_D 0.0818
#
# Batch 1/148  loss_pxl 0.1078  loss_adv 0.6953  loss_D 0.0746
# Batch 2/148  loss_pxl 0.0728  loss_adv 0.5219  loss_D 0.1301
# Batch 4/148  loss_pxl 0.1275  loss_adv 0.6711  loss_D 0.0412
# Batch 8/148  loss_pxl 0.0862  loss_adv 0.8593  loss_D 0.0744
# Batch 16/148  loss_pxl 0.0779  loss_adv 0.9329  loss_D 0.0727
# Batch 32/148  loss_pxl 0.0857  loss_adv 0.5514  loss_D 0.1107
# Batch 64/148  loss_pxl 0.1063  loss_adv 0.3768  loss_D 0.1595
# Batch 128/148  loss_pxl 0.0921  loss_adv 0.4942  loss_D 0.0877
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/28/index.html
# Epoch 29/150  train  loss_pxl 0.0921  loss_adv 0.6747  loss_D 0.1165
# Epoch 29/150  val  loss_pxl 0.1219  loss_adv 0.6250  loss_D 0.0953
#
# Batch 1/148  loss_pxl 0.0850  loss_adv 0.5114  loss_D 0.1104
# Batch 2/148  loss_pxl 0.0886  loss_adv 0.7915  loss_D 0.0560
# Batch 4/148  loss_pxl 0.0998  loss_adv 0.7818  loss_D 0.0968
# Batch 8/148  loss_pxl 0.1006  loss_adv 0.8576  loss_D 0.1326
# Batch 16/148  loss_pxl 0.0744  loss_adv 0.5116  loss_D 0.1241
# Batch 32/148  loss_pxl 0.1008  loss_adv 0.4572  loss_D 0.1043
# Batch 64/148  loss_pxl 0.1352  loss_adv 0.7314  loss_D 0.0593
# Batch 128/148  loss_pxl 0.0719  loss_adv 0.7503  loss_D 0.0532
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/29/index.html
# Epoch 30/150  train  loss_pxl 0.0915  loss_adv 0.6714  loss_D 0.1140
# Epoch 30/150  val  loss_pxl 0.1058  loss_adv 0.8004  loss_D 0.0989
#
# Batch 1/148  loss_pxl 0.0785  loss_adv 0.7375  loss_D 0.1312
# Batch 2/148  loss_pxl 0.0817  loss_adv 0.4794  loss_D 0.1395
# Batch 4/148  loss_pxl 0.0846  loss_adv 0.9139  loss_D 0.1382
# Batch 8/148  loss_pxl 0.0857  loss_adv 0.3745  loss_D 0.4606
# Batch 16/148  loss_pxl 0.0874  loss_adv 0.6674  loss_D 0.2005
# Batch 32/148  loss_pxl 0.0880  loss_adv 0.6211  loss_D 0.1252
# Batch 64/148  loss_pxl 0.0796  loss_adv 0.2852  loss_D 0.2074
# Batch 128/148  loss_pxl 0.1025  loss_adv 0.4476  loss_D 0.1342
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/30/index.html
# Epoch 31/150  train  loss_pxl 0.0933  loss_adv 0.4782  loss_D 0.1830
# Epoch 31/150  val  loss_pxl 0.1033  loss_adv 0.4454  loss_D 0.1489
#
# Batch 1/148  loss_pxl 0.0860  loss_adv 0.4591  loss_D 0.1202
# Batch 2/148  loss_pxl 0.0814  loss_adv 0.7160  loss_D 0.1802
# Batch 4/148  loss_pxl 0.0802  loss_adv 0.6908  loss_D 0.1967
# Batch 8/148  loss_pxl 0.0754  loss_adv 0.2527  loss_D 0.2950
# Batch 16/148  loss_pxl 0.0967  loss_adv 0.7828  loss_D 0.1284
# Batch 32/148  loss_pxl 0.1034  loss_adv 0.4745  loss_D 0.1127
# Batch 64/148  loss_pxl 0.0944  loss_adv 0.5703  loss_D 0.1930
# Batch 128/148  loss_pxl 0.1234  loss_adv 0.3453  loss_D 0.1256
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/31/index.html
# Epoch 32/150  train  loss_pxl 0.0920  loss_adv 0.4823  loss_D 0.1786
# Epoch 32/150  val  loss_pxl 0.1054  loss_adv 0.4736  loss_D 0.1340
#
# Batch 1/148  loss_pxl 0.0929  loss_adv 0.5474  loss_D 0.1088
# Batch 2/148  loss_pxl 0.1090  loss_adv 0.5394  loss_D 0.1494
# Batch 4/148  loss_pxl 0.0959  loss_adv 0.3943  loss_D 0.3233
# Batch 8/148  loss_pxl 0.0771  loss_adv 0.6929  loss_D 0.2884
# Batch 16/148  loss_pxl 0.0964  loss_adv 0.7127  loss_D 0.0845
# Batch 32/148  loss_pxl 0.0624  loss_adv 0.4679  loss_D 0.1541
# Batch 64/148  loss_pxl 0.0795  loss_adv 0.2709  loss_D 0.4411
# Batch 128/148  loss_pxl 0.0972  loss_adv 0.3153  loss_D 0.2312
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/32/index.html
# Epoch 33/150  train  loss_pxl 0.0889  loss_adv 0.4950  loss_D 0.3552
# Epoch 33/150  val  loss_pxl 0.1034  loss_adv 0.2643  loss_D 0.2261
#
# Batch 1/148  loss_pxl 0.0767  loss_adv 0.2931  loss_D 0.2486
# Batch 2/148  loss_pxl 0.0837  loss_adv 0.2673  loss_D 0.2283
# Batch 4/148  loss_pxl 0.0791  loss_adv 0.3005  loss_D 0.2183
# Batch 8/148  loss_pxl 0.0994  loss_adv 0.2894  loss_D 0.2063
# Batch 16/148  loss_pxl 0.0871  loss_adv 0.3342  loss_D 0.2116
# Batch 32/148  loss_pxl 0.0775  loss_adv 0.2502  loss_D 0.2228
# Batch 64/148  loss_pxl 0.0960  loss_adv 0.2879  loss_D 0.2104
# Batch 128/148  loss_pxl 0.1065  loss_adv 0.3500  loss_D 0.2044
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/33/index.html
# Epoch 34/150  train  loss_pxl 0.0868  loss_adv 0.3334  loss_D 0.2097
# Epoch 34/150  val  loss_pxl 0.1427  loss_adv 0.1932  loss_D 0.3400
#
# Batch 1/148  loss_pxl 0.0763  loss_adv 0.4878  loss_D 0.2123
# Batch 2/148  loss_pxl 0.0818  loss_adv 0.2593  loss_D 0.2257
# Batch 4/148  loss_pxl 0.0819  loss_adv 0.4630  loss_D 0.1914
# Batch 8/148  loss_pxl 0.0749  loss_adv 0.2693  loss_D 0.2267
# Batch 16/148  loss_pxl 0.1115  loss_adv 0.3761  loss_D 0.2041
# Batch 32/148  loss_pxl 0.1172  loss_adv 0.3417  loss_D 0.1835
# Batch 64/148  loss_pxl 0.0823  loss_adv 0.3655  loss_D 0.2194
# Batch 128/148  loss_pxl 0.0737  loss_adv 0.3912  loss_D 0.2330
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/34/index.html
# Epoch 35/150  train  loss_pxl 0.0868  loss_adv 0.3612  loss_D 0.2087
# Epoch 35/150  val  loss_pxl 0.0993  loss_adv 0.1657  loss_D 0.2438
#
# Batch 1/148  loss_pxl 0.1197  loss_adv 0.1386  loss_D 0.2411
# Batch 2/148  loss_pxl 0.0892  loss_adv 0.5466  loss_D 0.2049
# Batch 4/148  loss_pxl 0.0651  loss_adv 0.3830  loss_D 0.2241
# Batch 8/148  loss_pxl 0.0822  loss_adv 0.2827  loss_D 0.1922
# Batch 16/148  loss_pxl 0.0902  loss_adv 0.2690  loss_D 0.1850
# Batch 32/148  loss_pxl 0.0830  loss_adv 0.3670  loss_D 0.2108
# Batch 64/148  loss_pxl 0.0718  loss_adv 0.2308  loss_D 0.2122
# Batch 128/148  loss_pxl 0.1183  loss_adv 0.4144  loss_D 0.1239
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/35/index.html
# Epoch 36/150  train  loss_pxl 0.0939  loss_adv 0.3690  loss_D 0.2059
# Epoch 36/150  val  loss_pxl 0.1136  loss_adv 0.5488  loss_D 0.1655
#
# Batch 1/148  loss_pxl 0.0863  loss_adv 0.5523  loss_D 0.2546
# Batch 2/148  loss_pxl 0.0870  loss_adv 0.2655  loss_D 0.3036
# Batch 4/148  loss_pxl 0.1049  loss_adv 0.5239  loss_D 0.1574
# Batch 8/148  loss_pxl 0.0741  loss_adv 0.3896  loss_D 0.1824
# Batch 16/148  loss_pxl 0.1058  loss_adv 0.3912  loss_D 0.2364
# Batch 32/148  loss_pxl 0.0755  loss_adv 0.3445  loss_D 0.1577
# Batch 64/148  loss_pxl 0.0802  loss_adv 0.5752  loss_D 0.2497
# Batch 128/148  loss_pxl 0.0803  loss_adv 0.4071  loss_D 0.1576
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/36/index.html
# Epoch 37/150  train  loss_pxl 0.0882  loss_adv 0.3916  loss_D 0.1969
# Epoch 37/150  val  loss_pxl 0.1120  loss_adv 0.3869  loss_D 0.1658
#
# Batch 1/148  loss_pxl 0.0852  loss_adv 0.3670  loss_D 0.1829
# Batch 2/148  loss_pxl 0.0949  loss_adv 0.4681  loss_D 0.1437
# Batch 4/148  loss_pxl 0.1054  loss_adv 0.3165  loss_D 0.1965
# Batch 8/148  loss_pxl 0.0938  loss_adv 0.3875  loss_D 0.1990
# Batch 16/148  loss_pxl 0.0944  loss_adv 0.4703  loss_D 0.1833
# Batch 32/148  loss_pxl 0.0747  loss_adv 0.3953  loss_D 0.2089
# Batch 64/148  loss_pxl 0.0839  loss_adv 0.3253  loss_D 0.1787
# Batch 128/148  loss_pxl 0.0764  loss_adv 0.3746  loss_D 0.2214
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/37/index.html
# Epoch 38/150  train  loss_pxl 0.0868  loss_adv 0.4027  loss_D 0.1955
# Epoch 38/150  val  loss_pxl 0.1091  loss_adv 0.5271  loss_D 0.1533
#
# Batch 1/148  loss_pxl 0.0725  loss_adv 0.4220  loss_D 0.2245
# Batch 2/148  loss_pxl 0.1098  loss_adv 0.3789  loss_D 0.1728
# Batch 4/148  loss_pxl 0.1007  loss_adv 0.3614  loss_D 0.1653
# Batch 8/148  loss_pxl 0.0780  loss_adv 0.5598  loss_D 0.2395
# Batch 16/148  loss_pxl 0.0687  loss_adv 0.8001  loss_D 0.2790
# Batch 32/148  loss_pxl 0.0877  loss_adv 0.5694  loss_D 0.1887
# Batch 64/148  loss_pxl 0.0801  loss_adv 0.4224  loss_D 0.2501
# Batch 128/148  loss_pxl 0.0764  loss_adv 0.2148  loss_D 0.2164
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/38/index.html
# Epoch 39/150  train  loss_pxl 0.0847  loss_adv 0.4192  loss_D 0.1900
# Epoch 39/150  val  loss_pxl 0.0971  loss_adv 0.3856  loss_D 0.1640
#
# Batch 1/148  loss_pxl 0.0724  loss_adv 0.4019  loss_D 0.1753
# Batch 2/148  loss_pxl 0.0689  loss_adv 0.3880  loss_D 0.1779
# Batch 4/148  loss_pxl 0.0759  loss_adv 0.3471  loss_D 0.1903
# Batch 8/148  loss_pxl 0.0938  loss_adv 0.4664  loss_D 0.2218
# Batch 16/148  loss_pxl 0.0883  loss_adv 0.5410  loss_D 0.2600
# Batch 32/148  loss_pxl 0.0772  loss_adv 0.5599  loss_D 0.0943
# Batch 64/148  loss_pxl 0.0748  loss_adv 0.3671  loss_D 0.2122
# Batch 128/148  loss_pxl 0.0705  loss_adv 0.5280  loss_D 0.2106
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/39/index.html
# Epoch 40/150  train  loss_pxl 0.0847  loss_adv 0.4270  loss_D 0.1895
# Epoch 40/150  val  loss_pxl 0.1038  loss_adv 0.3272  loss_D 0.1723
#
# Batch 1/148  loss_pxl 0.0762  loss_adv 0.3222  loss_D 0.2390
# Batch 2/148  loss_pxl 0.0817  loss_adv 0.1979  loss_D 0.2326
# Batch 4/148  loss_pxl 0.0919  loss_adv 0.3875  loss_D 0.1784
# Batch 8/148  loss_pxl 0.0646  loss_adv 0.4792  loss_D 0.1644
# Batch 16/148  loss_pxl 0.0640  loss_adv 0.4944  loss_D 0.2380
# Batch 32/148  loss_pxl 0.0719  loss_adv 0.5233  loss_D 0.1854
# Batch 64/148  loss_pxl 0.0602  loss_adv 0.3480  loss_D 0.2703
# Batch 128/148  loss_pxl 0.0917  loss_adv 0.2786  loss_D 0.2087
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/40/index.html
# Epoch 41/150  train  loss_pxl 0.0840  loss_adv 0.4329  loss_D 0.1870
# Epoch 41/150  val  loss_pxl 0.0962  loss_adv 0.3381  loss_D 0.1552
#
# Batch 1/148  loss_pxl 0.0791  loss_adv 0.3028  loss_D 0.1766
# Batch 2/148  loss_pxl 0.0637  loss_adv 0.5019  loss_D 0.1591
# Batch 4/148  loss_pxl 0.1080  loss_adv 0.7602  loss_D 0.1725
# Batch 8/148  loss_pxl 0.0738  loss_adv 0.6021  loss_D 0.1537
# Batch 16/148  loss_pxl 0.0808  loss_adv 0.5854  loss_D 0.1897
# Batch 32/148  loss_pxl 0.0715  loss_adv 0.5081  loss_D 0.1861
# Batch 64/148  loss_pxl 0.0906  loss_adv 0.1508  loss_D 0.2370
# Batch 128/148  loss_pxl 0.0880  loss_adv 0.3675  loss_D 0.1564
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/41/index.html
# Epoch 42/150  train  loss_pxl 0.0840  loss_adv 0.4412  loss_D 0.1852
# Epoch 42/150  val  loss_pxl 0.1028  loss_adv 0.2831  loss_D 0.1989
#
# Batch 1/148  loss_pxl 0.0764  loss_adv 0.2443  loss_D 0.2356
# Batch 2/148  loss_pxl 0.0736  loss_adv 0.5054  loss_D 0.2856
# Batch 4/148  loss_pxl 0.0701  loss_adv 0.5647  loss_D 0.2210
# Batch 8/148  loss_pxl 0.0916  loss_adv 0.4074  loss_D 0.1594
# Batch 16/148  loss_pxl 0.0824  loss_adv 0.2559  loss_D 0.2754
# Batch 32/148  loss_pxl 0.0839  loss_adv 0.6528  loss_D 0.1684
# Batch 64/148  loss_pxl 0.0960  loss_adv 0.7795  loss_D 0.1541
# Batch 128/148  loss_pxl 0.0845  loss_adv 0.2514  loss_D 0.1582
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/42/index.html
# Epoch 43/150  train  loss_pxl 0.0828  loss_adv 0.4436  loss_D 0.1876
# Epoch 43/150  val  loss_pxl 0.1003  loss_adv 0.2609  loss_D 0.1867
#
# Batch 1/148  loss_pxl 0.0800  loss_adv 0.2681  loss_D 0.1707
# Batch 2/148  loss_pxl 0.0908  loss_adv 0.6153  loss_D 0.1699
# Batch 4/148  loss_pxl 0.0755  loss_adv 0.2595  loss_D 0.1653
# Batch 8/148  loss_pxl 0.0671  loss_adv 0.5502  loss_D 0.1105
# Batch 16/148  loss_pxl 0.1089  loss_adv 0.5573  loss_D 0.1431
# Batch 32/148  loss_pxl 0.0781  loss_adv 0.5288  loss_D 0.1641
# Batch 64/148  loss_pxl 0.0839  loss_adv 0.6231  loss_D 0.1688
# Batch 128/148  loss_pxl 0.0706  loss_adv 0.2240  loss_D 0.2269
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/43/index.html
# Epoch 44/150  train  loss_pxl 0.0816  loss_adv 0.4579  loss_D 0.1839
# Epoch 44/150  val  loss_pxl 0.0974  loss_adv 0.4224  loss_D 0.1526
#
# Batch 1/148  loss_pxl 0.0671  loss_adv 0.3894  loss_D 0.1761
# Batch 2/148  loss_pxl 0.0850  loss_adv 0.6136  loss_D 0.1920
# Batch 4/148  loss_pxl 0.0830  loss_adv 0.4506  loss_D 0.2060
# Batch 8/148  loss_pxl 0.0892  loss_adv 0.7066  loss_D 0.1124
# Batch 16/148  loss_pxl 0.0805  loss_adv 0.4585  loss_D 0.1775
# Batch 32/148  loss_pxl 0.0670  loss_adv 0.3563  loss_D 0.1754
# Batch 64/148  loss_pxl 0.0669  loss_adv 0.4203  loss_D 0.1687
# Batch 128/148  loss_pxl 0.0786  loss_adv 0.4650  loss_D 0.1628
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/44/index.html
# Epoch 45/150  train  loss_pxl 0.0814  loss_adv 0.4447  loss_D 0.1836
# Epoch 45/150  val  loss_pxl 0.0998  loss_adv 0.4551  loss_D 0.1886
#
# Batch 1/148  loss_pxl 0.0885  loss_adv 0.4312  loss_D 0.2188
# Batch 2/148  loss_pxl 0.0608  loss_adv 0.4687  loss_D 0.2178
# Batch 4/148  loss_pxl 0.0758  loss_adv 0.3431  loss_D 0.1587
# Batch 8/148  loss_pxl 0.0651  loss_adv 0.7472  loss_D 0.2233
# Batch 16/148  loss_pxl 0.0670  loss_adv 0.3640  loss_D 0.1439
# Batch 32/148  loss_pxl 0.0963  loss_adv 0.3613  loss_D 0.1435
# Batch 64/148  loss_pxl 0.0961  loss_adv 0.6018  loss_D 0.1227
# Batch 128/148  loss_pxl 0.0616  loss_adv 0.3859  loss_D 0.2337
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/45/index.html
# Epoch 46/150  train  loss_pxl 0.0806  loss_adv 0.4598  loss_D 0.1829
# Epoch 46/150  val  loss_pxl 0.1136  loss_adv 0.5253  loss_D 0.1611
#
# Batch 1/148  loss_pxl 0.0615  loss_adv 0.6070  loss_D 0.1598
# Batch 2/148  loss_pxl 0.0780  loss_adv 0.3301  loss_D 0.1850
# Batch 4/148  loss_pxl 0.0752  loss_adv 0.4680  loss_D 0.2718
# Batch 8/148  loss_pxl 0.0844  loss_adv 0.3759  loss_D 0.1426
# Batch 16/148  loss_pxl 0.0944  loss_adv 0.3340  loss_D 0.2209
# Batch 32/148  loss_pxl 0.0707  loss_adv 0.6079  loss_D 0.1816
# Batch 64/148  loss_pxl 0.0792  loss_adv 0.5014  loss_D 0.1686
# Batch 128/148  loss_pxl 0.0754  loss_adv 0.5216  loss_D 0.1295
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/46/index.html
# Epoch 47/150  train  loss_pxl 0.0797  loss_adv 0.4604  loss_D 0.1804
# Epoch 47/150  val  loss_pxl 0.0967  loss_adv 0.6126  loss_D 0.1488
#
# Batch 1/148  loss_pxl 0.0750  loss_adv 0.6594  loss_D 0.1501
# Batch 2/148  loss_pxl 0.0597  loss_adv 0.3927  loss_D 0.1659
# Batch 4/148  loss_pxl 0.0639  loss_adv 0.4227  loss_D 0.1611
# Batch 8/148  loss_pxl 0.0744  loss_adv 0.8933  loss_D 0.1867
# Batch 16/148  loss_pxl 0.0881  loss_adv 0.3159  loss_D 0.1544
# Batch 32/148  loss_pxl 0.0949  loss_adv 0.6654  loss_D 0.0980
# Batch 64/148  loss_pxl 0.0685  loss_adv 0.2648  loss_D 0.2461
# Batch 128/148  loss_pxl 0.0593  loss_adv 0.5192  loss_D 0.1990
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/47/index.html
# Epoch 48/150  train  loss_pxl 0.0776  loss_adv 0.4710  loss_D 0.1804
# Epoch 48/150  val  loss_pxl 0.1053  loss_adv 0.5847  loss_D 0.1801
#
# Batch 1/148  loss_pxl 0.0716  loss_adv 0.5242  loss_D 0.2212
# Batch 2/148  loss_pxl 0.0683  loss_adv 0.3876  loss_D 0.1997
# Batch 4/148  loss_pxl 0.0729  loss_adv 0.5182  loss_D 0.1566
# Batch 8/148  loss_pxl 0.0963  loss_adv 0.5111  loss_D 0.1854
# Batch 16/148  loss_pxl 0.0789  loss_adv 0.7586  loss_D 0.2590
# Batch 32/148  loss_pxl 0.0628  loss_adv 0.5321  loss_D 0.2476
# Batch 64/148  loss_pxl 0.0763  loss_adv 0.5556  loss_D 0.1381
# Batch 128/148  loss_pxl 0.0865  loss_adv 0.6404  loss_D 0.1149
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/48/index.html
# Epoch 49/150  train  loss_pxl 0.0796  loss_adv 0.4692  loss_D 0.1811
# Epoch 49/150  val  loss_pxl 0.1042  loss_adv 0.3908  loss_D 0.1663
#
# Batch 1/148  loss_pxl 0.0835  loss_adv 0.3643  loss_D 0.1401
# Batch 2/148  loss_pxl 0.0776  loss_adv 0.5264  loss_D 0.1884
# Batch 4/148  loss_pxl 0.0754  loss_adv 0.3159  loss_D 0.1572
# Batch 8/148  loss_pxl 0.0769  loss_adv 0.5701  loss_D 0.1729
# Batch 16/148  loss_pxl 0.0698  loss_adv 0.2661  loss_D 0.2211
# Batch 32/148  loss_pxl 0.0923  loss_adv 0.3509  loss_D 0.1784
# Batch 64/148  loss_pxl 0.0746  loss_adv 0.3512  loss_D 0.2156
# Batch 128/148  loss_pxl 0.0695  loss_adv 0.5936  loss_D 0.2195
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/49/index.html
# Epoch 50/150  train  loss_pxl 0.0773  loss_adv 0.4715  loss_D 0.1761
# Epoch 50/150  val  loss_pxl 0.1049  loss_adv 0.4980  loss_D 0.1314
#
# Batch 1/148  loss_pxl 0.0545  loss_adv 0.5235  loss_D 0.1383
# Batch 2/148  loss_pxl 0.0863  loss_adv 0.2597  loss_D 0.1973
# Batch 4/148  loss_pxl 0.0838  loss_adv 0.5428  loss_D 0.1456
# Batch 8/148  loss_pxl 0.0794  loss_adv 0.2043  loss_D 0.2475
# Batch 16/148  loss_pxl 0.0593  loss_adv 0.5018  loss_D 0.1698
# Batch 32/148  loss_pxl 0.0720  loss_adv 0.2473  loss_D 0.2249
# Batch 64/148  loss_pxl 0.0510  loss_adv 0.6971  loss_D 0.2116
# Batch 128/148  loss_pxl 0.0694  loss_adv 0.4939  loss_D 0.1726
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/50/index.html
# Epoch 51/150  train  loss_pxl 0.0774  loss_adv 0.4738  loss_D 0.1806
# Epoch 51/150  val  loss_pxl 0.1021  loss_adv 0.4558  loss_D 0.1603
#
# Batch 1/148  loss_pxl 0.0691  loss_adv 0.5210  loss_D 0.1496
# Batch 2/148  loss_pxl 0.0730  loss_adv 0.3691  loss_D 0.1359
# Batch 4/148  loss_pxl 0.0569  loss_adv 0.5897  loss_D 0.2151
# Batch 8/148  loss_pxl 0.0869  loss_adv 0.2408  loss_D 0.1745
# Batch 16/148  loss_pxl 0.0742  loss_adv 0.5856  loss_D 0.0772
# Batch 32/148  loss_pxl 0.0684  loss_adv 0.4959  loss_D 0.1965
# Batch 64/148  loss_pxl 0.0742  loss_adv 0.2260  loss_D 0.2225
# Batch 128/148  loss_pxl 0.0841  loss_adv 0.3154  loss_D 0.1786
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/51/index.html
# Epoch 52/150  train  loss_pxl 0.0755  loss_adv 0.4764  loss_D 0.1737
# Epoch 52/150  val  loss_pxl 0.1020  loss_adv 0.7590  loss_D 0.1662
#
# Batch 1/148  loss_pxl 0.0932  loss_adv 0.7071  loss_D 0.1762
# Batch 2/148  loss_pxl 0.0830  loss_adv 0.5046  loss_D 0.1116
# Batch 4/148  loss_pxl 0.0711  loss_adv 0.3312  loss_D 0.1865
# Batch 8/148  loss_pxl 0.0585  loss_adv 0.5142  loss_D 0.3040
# Batch 16/148  loss_pxl 0.0852  loss_adv 0.2807  loss_D 0.1664
# Batch 32/148  loss_pxl 0.0748  loss_adv 0.3931  loss_D 0.1556
# Batch 64/148  loss_pxl 0.0883  loss_adv 0.2741  loss_D 0.1852
# Batch 128/148  loss_pxl 0.0948  loss_adv 0.7388  loss_D 0.2013
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/52/index.html
# Epoch 53/150  train  loss_pxl 0.0759  loss_adv 0.4878  loss_D 0.1759
# Epoch 53/150  val  loss_pxl 0.1088  loss_adv 0.6542  loss_D 0.1986
#
# Batch 1/148  loss_pxl 0.0959  loss_adv 0.6867  loss_D 0.1474
# Batch 2/148  loss_pxl 0.0763  loss_adv 0.3669  loss_D 0.1629
# Batch 4/148  loss_pxl 0.0750  loss_adv 0.2270  loss_D 0.2636
# Batch 8/148  loss_pxl 0.0791  loss_adv 0.3905  loss_D 0.0978
# Batch 16/148  loss_pxl 0.0684  loss_adv 0.4362  loss_D 0.1591
# Batch 32/148  loss_pxl 0.0553  loss_adv 0.6467  loss_D 0.1689
# Batch 64/148  loss_pxl 0.0663  loss_adv 0.3959  loss_D 0.1597
# Batch 128/148  loss_pxl 0.0737  loss_adv 0.7544  loss_D 0.1777
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/53/index.html
# Epoch 54/150  train  loss_pxl 0.0741  loss_adv 0.4854  loss_D 0.1753
# Epoch 54/150  val  loss_pxl 0.1008  loss_adv 0.2914  loss_D 0.1793
#
# Batch 1/148  loss_pxl 0.0853  loss_adv 0.2883  loss_D 0.1656
# Batch 2/148  loss_pxl 0.0577  loss_adv 0.6901  loss_D 0.2710
# Batch 4/148  loss_pxl 0.0898  loss_adv 0.3008  loss_D 0.1508
# Batch 8/148  loss_pxl 0.0980  loss_adv 0.4017  loss_D 0.1011
# Batch 16/148  loss_pxl 0.0953  loss_adv 0.3945  loss_D 0.1144
# Batch 32/148  loss_pxl 0.0652  loss_adv 0.4055  loss_D 0.1981
# Batch 64/148  loss_pxl 0.0701  loss_adv 0.5993  loss_D 0.2131
# Batch 128/148  loss_pxl 0.0855  loss_adv 6.1355  loss_D 6.5398
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/54/index.html
# Epoch 55/150  train  loss_pxl 0.0748  loss_adv 0.5432  loss_D 0.2717
# Epoch 55/150  val  loss_pxl 0.1057  loss_adv 0.2889  loss_D 0.2262
#
# Batch 1/148  loss_pxl 0.0697  loss_adv 0.2733  loss_D 0.2389
# Batch 2/148  loss_pxl 0.0894  loss_adv 0.2706  loss_D 0.2080
# Batch 4/148  loss_pxl 0.0621  loss_adv 0.3054  loss_D 0.2388
# Batch 8/148  loss_pxl 0.0829  loss_adv 0.2758  loss_D 0.2198
# Batch 16/148  loss_pxl 0.0758  loss_adv 0.2893  loss_D 0.2275
# Batch 32/148  loss_pxl 0.0732  loss_adv 0.2906  loss_D 0.2123
# Batch 64/148  loss_pxl 0.0815  loss_adv 0.2501  loss_D 0.2295
# Batch 128/148  loss_pxl 0.0836  loss_adv 0.3891  loss_D 0.1909
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/55/index.html
# Epoch 56/150  train  loss_pxl 0.0736  loss_adv 0.3334  loss_D 0.2110
# Epoch 56/150  val  loss_pxl 0.0966  loss_adv 0.4009  loss_D 0.1723
#
# Batch 1/148  loss_pxl 0.0714  loss_adv 0.3427  loss_D 0.1872
# Batch 2/148  loss_pxl 0.0739  loss_adv 0.3758  loss_D 0.1943
# Batch 4/148  loss_pxl 0.0782  loss_adv 0.2706  loss_D 0.1666
# Batch 8/148  loss_pxl 0.0650  loss_adv 0.2810  loss_D 0.1730
# Batch 16/148  loss_pxl 0.0581  loss_adv 0.2756  loss_D 0.2408
# Batch 32/148  loss_pxl 0.0826  loss_adv 0.3260  loss_D 0.1576
# Batch 64/148  loss_pxl 0.0585  loss_adv 0.3772  loss_D 0.1639
# Batch 128/148  loss_pxl 0.0760  loss_adv 0.1819  loss_D 0.2184
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/56/index.html
# Epoch 57/150  train  loss_pxl 0.0722  loss_adv 0.3751  loss_D 0.1970
# Epoch 57/150  val  loss_pxl 0.0988  loss_adv 0.4716  loss_D 0.1456
#
# Batch 1/148  loss_pxl 0.0748  loss_adv 0.4024  loss_D 0.2219
# Batch 2/148  loss_pxl 0.0656  loss_adv 0.3614  loss_D 0.1917
# Batch 4/148  loss_pxl 0.0750  loss_adv 0.3084  loss_D 0.1632
# Batch 8/148  loss_pxl 0.0752  loss_adv 0.2682  loss_D 0.2049
# Batch 16/148  loss_pxl 0.0702  loss_adv 0.5256  loss_D 0.1571
# Batch 32/148  loss_pxl 0.0738  loss_adv 0.4562  loss_D 0.1967
# Batch 64/148  loss_pxl 0.0618  loss_adv 0.5312  loss_D 0.2419
# Batch 128/148  loss_pxl 0.0574  loss_adv 0.5660  loss_D 0.2072
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/57/index.html
# Epoch 58/150  train  loss_pxl 0.0729  loss_adv 0.4064  loss_D 0.1859
# Epoch 58/150  val  loss_pxl 0.1225  loss_adv 0.2078  loss_D 0.2394
#
# Batch 1/148  loss_pxl 0.0740  loss_adv 0.3657  loss_D 0.1420
# Batch 2/148  loss_pxl 0.0687  loss_adv 0.2324  loss_D 0.2405
# Batch 4/148  loss_pxl 0.0601  loss_adv 0.5432  loss_D 0.2265
# Batch 8/148  loss_pxl 0.0786  loss_adv 0.5221  loss_D 0.1700
# Batch 16/148  loss_pxl 0.0635  loss_adv 0.4827  loss_D 0.1278
# Batch 32/148  loss_pxl 0.0725  loss_adv 0.4228  loss_D 0.1492
# Batch 64/148  loss_pxl 0.0743  loss_adv 0.2224  loss_D 0.1958
# Batch 128/148  loss_pxl 0.0915  loss_adv 0.3321  loss_D 0.1621
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/58/index.html
# Epoch 59/150  train  loss_pxl 0.0709  loss_adv 0.4409  loss_D 0.1843
# Epoch 59/150  val  loss_pxl 0.1357  loss_adv 0.5473  loss_D 0.1374
#
# Batch 1/148  loss_pxl 0.0690  loss_adv 0.4493  loss_D 0.1519
# Batch 2/148  loss_pxl 0.0634  loss_adv 0.4327  loss_D 0.1389
# Batch 4/148  loss_pxl 0.0640  loss_adv 0.2558  loss_D 0.2283
# Batch 8/148  loss_pxl 0.0632  loss_adv 0.3867  loss_D 0.1453
# Batch 16/148  loss_pxl 0.0830  loss_adv 0.6545  loss_D 0.2033
# Batch 32/148  loss_pxl 0.0644  loss_adv 0.4348  loss_D 0.2124
# Batch 64/148  loss_pxl 0.0754  loss_adv 0.3741  loss_D 0.1708
# Batch 128/148  loss_pxl 0.0760  loss_adv 0.2054  loss_D 0.1947
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/59/index.html
# Epoch 60/150  train  loss_pxl 0.0709  loss_adv 0.4513  loss_D 0.1765
# Epoch 60/150  val  loss_pxl 0.0970  loss_adv 0.5042  loss_D 0.1511
#
# Batch 1/148  loss_pxl 0.0592  loss_adv 0.4721  loss_D 0.2231
# Batch 2/148  loss_pxl 0.0764  loss_adv 0.3216  loss_D 0.1713
# Batch 4/148  loss_pxl 0.0831  loss_adv 0.3120  loss_D 0.2721
# Batch 8/148  loss_pxl 0.0808  loss_adv 0.1794  loss_D 0.2409
# Batch 16/148  loss_pxl 0.0599  loss_adv 0.3435  loss_D 0.2227
# Batch 32/148  loss_pxl 0.0685  loss_adv 0.3812  loss_D 0.2151
# Batch 64/148  loss_pxl 0.0781  loss_adv 0.2568  loss_D 0.2472
# Batch 128/148  loss_pxl 0.0890  loss_adv 0.3785  loss_D 0.2145
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/60/index.html
# Epoch 61/150  train  loss_pxl 0.0751  loss_adv 0.3592  loss_D 0.2176
# Epoch 61/150  val  loss_pxl 0.1045  loss_adv 0.2911  loss_D 0.1966
#
# Batch 1/148  loss_pxl 0.0863  loss_adv 0.2777  loss_D 0.2276
# Batch 2/148  loss_pxl 0.0729  loss_adv 0.2701  loss_D 0.2053
# Batch 4/148  loss_pxl 0.0898  loss_adv 0.3424  loss_D 0.1638
# Batch 8/148  loss_pxl 0.0618  loss_adv 0.4221  loss_D 0.1707
# Batch 16/148  loss_pxl 0.0808  loss_adv 0.3498  loss_D 0.2513
# Batch 32/148  loss_pxl 0.0774  loss_adv 0.4096  loss_D 0.1477
# ...
# Batch 128/148  loss_pxl 0.0537  loss_adv 0.4914  loss_D 0.1770
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/129/index.html
# Epoch 130/150  train  loss_pxl 0.0511  loss_adv 0.3964  loss_D 0.2060
# Epoch 130/150  val  loss_pxl 0.0993  loss_adv 0.6051  loss_D 0.2247
#
# Batch 1/148  loss_pxl 0.0452  loss_adv 0.6450  loss_D 0.1932
# Batch 2/148  loss_pxl 0.0625  loss_adv 0.2516  loss_D 0.2062
# Batch 4/148  loss_pxl 0.0499  loss_adv 0.5272  loss_D 0.1806
# Batch 8/148  loss_pxl 0.0491  loss_adv 0.3947  loss_D 0.1784
# Batch 16/148  loss_pxl 0.0579  loss_adv 0.5457  loss_D 0.1367
# Batch 32/148  loss_pxl 0.0466  loss_adv 0.3347  loss_D 0.1811
# Batch 64/148  loss_pxl 0.0571  loss_adv 0.4268  loss_D 0.1701
# Batch 128/148  loss_pxl 0.0513  loss_adv 0.7425  loss_D 0.2074
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/130/index.html
# Epoch 131/150  train  loss_pxl 0.0511  loss_adv 0.3927  loss_D 0.2062
# Epoch 131/150  val  loss_pxl 0.1042  loss_adv 0.3192  loss_D 0.1956
#
# Batch 1/148  loss_pxl 0.0492  loss_adv 0.2203  loss_D 0.2119
# Batch 2/148  loss_pxl 0.0512  loss_adv 0.4521  loss_D 0.2294
# Batch 4/148  loss_pxl 0.0464  loss_adv 0.3656  loss_D 0.1969
# Batch 8/148  loss_pxl 0.0447  loss_adv 0.3940  loss_D 0.1830
# Batch 16/148  loss_pxl 0.0422  loss_adv 0.3598  loss_D 0.1852
# Batch 32/148  loss_pxl 0.0402  loss_adv 0.4318  loss_D 0.2447
# Batch 64/148  loss_pxl 0.0525  loss_adv 0.2430  loss_D 0.2282
# Batch 128/148  loss_pxl 0.0612  loss_adv 0.2377  loss_D 0.2006
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/131/index.html
# Epoch 132/150  train  loss_pxl 0.0507  loss_adv 0.3908  loss_D 0.2074
# Epoch 132/150  val  loss_pxl 0.1109  loss_adv 0.3628  loss_D 0.1993
#
# Batch 1/148  loss_pxl 0.0580  loss_adv 0.3712  loss_D 0.2200
# Batch 2/148  loss_pxl 0.0403  loss_adv 0.2867  loss_D 0.2211
# Batch 4/148  loss_pxl 0.0473  loss_adv 0.5645  loss_D 0.1939
# Batch 8/148  loss_pxl 0.0476  loss_adv 0.4627  loss_D 0.2154
# Batch 16/148  loss_pxl 0.0423  loss_adv 0.4589  loss_D 0.2453
# Batch 32/148  loss_pxl 0.0533  loss_adv 0.3264  loss_D 0.2147
# Batch 64/148  loss_pxl 0.0638  loss_adv 0.4283  loss_D 0.1738
# Batch 128/148  loss_pxl 0.0436  loss_adv 0.4356  loss_D 0.1697
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/132/index.html
# Epoch 133/150  train  loss_pxl 0.0506  loss_adv 0.3938  loss_D 0.2050
# Epoch 133/150  val  loss_pxl 0.1026  loss_adv 0.5165  loss_D 0.1952
#
# Batch 1/148  loss_pxl 0.0491  loss_adv 0.4845  loss_D 0.1601
# Batch 2/148  loss_pxl 0.0431  loss_adv 0.4839  loss_D 0.2067
# Batch 4/148  loss_pxl 0.0448  loss_adv 0.2032  loss_D 0.2151
# Batch 8/148  loss_pxl 0.0469  loss_adv 0.2925  loss_D 0.1864
# Batch 16/148  loss_pxl 0.0538  loss_adv 0.2541  loss_D 0.1847
# Batch 32/148  loss_pxl 0.0475  loss_adv 0.3463  loss_D 0.1702
# Batch 64/148  loss_pxl 0.0539  loss_adv 0.4194  loss_D 0.1812
# Batch 128/148  loss_pxl 0.0486  loss_adv 0.3041  loss_D 0.2505
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/133/index.html
# Epoch 134/150  train  loss_pxl 0.0506  loss_adv 0.3938  loss_D 0.2051
# Epoch 134/150  val  loss_pxl 0.0992  loss_adv 0.5152  loss_D 0.1879
#
# Batch 1/148  loss_pxl 0.0587  loss_adv 0.4045  loss_D 0.1802
# Batch 2/148  loss_pxl 0.0534  loss_adv 0.4789  loss_D 0.1897
# Batch 4/148  loss_pxl 0.0620  loss_adv 0.4494  loss_D 0.2238
# Batch 8/148  loss_pxl 0.0470  loss_adv 0.4136  loss_D 0.2196
# Batch 16/148  loss_pxl 0.0414  loss_adv 0.4767  loss_D 0.2212
# Batch 32/148  loss_pxl 0.0606  loss_adv 0.3783  loss_D 0.1443
# Batch 64/148  loss_pxl 0.0561  loss_adv 0.4524  loss_D 0.2309
# Batch 128/148  loss_pxl 0.0587  loss_adv 0.3321  loss_D 0.1679
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/134/index.html
# Epoch 135/150  train  loss_pxl 0.0510  loss_adv 0.4012  loss_D 0.2027
# Epoch 135/150  val  loss_pxl 0.0974  loss_adv 0.2757  loss_D 0.2010
#
# Batch 1/148  loss_pxl 0.0508  loss_adv 0.2429  loss_D 0.2127
# Batch 2/148  loss_pxl 0.0437  loss_adv 0.4167  loss_D 0.2132
# Batch 4/148  loss_pxl 0.0510  loss_adv 0.3380  loss_D 0.1836
# Batch 8/148  loss_pxl 0.0438  loss_adv 0.2405  loss_D 0.2183
# Batch 16/148  loss_pxl 0.0568  loss_adv 0.3730  loss_D 0.1829
# Batch 32/148  loss_pxl 0.0511  loss_adv 0.4757  loss_D 0.2114
# Batch 64/148  loss_pxl 0.0457  loss_adv 0.5177  loss_D 0.2513
# Batch 128/148  loss_pxl 0.0411  loss_adv 0.3471  loss_D 0.2139
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/135/index.html
# Epoch 136/150  train  loss_pxl 0.0500  loss_adv 0.3884  loss_D 0.2098
# Epoch 136/150  val  loss_pxl 0.0959  loss_adv 0.5085  loss_D 0.2040
#
# Batch 1/148  loss_pxl 0.0660  loss_adv 0.4278  loss_D 0.1687
# Batch 2/148  loss_pxl 0.0496  loss_adv 0.5153  loss_D 0.2214
# Batch 4/148  loss_pxl 0.0521  loss_adv 0.3902  loss_D 0.2119
# Batch 8/148  loss_pxl 0.0469  loss_adv 0.2965  loss_D 0.2104
# Batch 16/148  loss_pxl 0.0448  loss_adv 0.3360  loss_D 0.1831
# Batch 32/148  loss_pxl 0.0523  loss_adv 0.5254  loss_D 0.1577
# Batch 64/148  loss_pxl 0.0543  loss_adv 0.4729  loss_D 0.2074
# Batch 128/148  loss_pxl 0.0479  loss_adv 0.2691  loss_D 0.2099
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/136/index.html
# Epoch 137/150  train  loss_pxl 0.0495  loss_adv 0.3903  loss_D 0.2052
# Epoch 137/150  val  loss_pxl 0.0989  loss_adv 0.5783  loss_D 0.2076
#
# Batch 1/148  loss_pxl 0.0478  loss_adv 0.5732  loss_D 0.1712
# Batch 2/148  loss_pxl 0.0547  loss_adv 0.3875  loss_D 0.1708
# Batch 4/148  loss_pxl 0.0442  loss_adv 0.3423  loss_D 0.2330
# Batch 8/148  loss_pxl 0.0451  loss_adv 0.2539  loss_D 0.2285
# Batch 16/148  loss_pxl 0.0566  loss_adv 0.3385  loss_D 0.1793
# Batch 32/148  loss_pxl 0.0551  loss_adv 0.3442  loss_D 0.1735
# Batch 64/148  loss_pxl 0.0442  loss_adv 0.3884  loss_D 0.1854
# Batch 128/148  loss_pxl 0.0678  loss_adv 0.4392  loss_D 0.1749
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/137/index.html
# Epoch 138/150  train  loss_pxl 0.0497  loss_adv 0.3977  loss_D 0.2049
# Epoch 138/150  val  loss_pxl 0.0984  loss_adv 0.5934  loss_D 0.1829
#
# Batch 1/148  loss_pxl 0.0557  loss_adv 0.4222  loss_D 0.2081
# Batch 2/148  loss_pxl 0.0503  loss_adv 0.4827  loss_D 0.1755
# Batch 4/148  loss_pxl 0.0564  loss_adv 0.3407  loss_D 0.2001
# Batch 8/148  loss_pxl 0.0547  loss_adv 0.5640  loss_D 0.1901
# Batch 16/148  loss_pxl 0.0523  loss_adv 0.4851  loss_D 0.2013
# Batch 32/148  loss_pxl 0.0465  loss_adv 0.5481  loss_D 0.2175
# Batch 64/148  loss_pxl 0.0483  loss_adv 0.2961  loss_D 0.2192
# Batch 128/148  loss_pxl 0.0505  loss_adv 0.3213  loss_D 0.1740
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/138/index.html
# Epoch 139/150  train  loss_pxl 0.0495  loss_adv 0.3984  loss_D 0.2061
# Epoch 139/150  val  loss_pxl 0.0955  loss_adv 0.5661  loss_D 0.2017
#
# Batch 1/148  loss_pxl 0.0472  loss_adv 0.4328  loss_D 0.2098
# Batch 2/148  loss_pxl 0.0521  loss_adv 0.3040  loss_D 0.1992
# Batch 4/148  loss_pxl 0.0360  loss_adv 0.3321  loss_D 0.2169
# Batch 8/148  loss_pxl 0.0439  loss_adv 0.3422  loss_D 0.1939
# Batch 16/148  loss_pxl 0.0462  loss_adv 0.4020  loss_D 0.2562
# Batch 32/148  loss_pxl 0.0527  loss_adv 0.4681  loss_D 0.1994
# Batch 64/148  loss_pxl 0.0460  loss_adv 0.2952  loss_D 0.2537
# Batch 128/148  loss_pxl 0.0516  loss_adv 0.5307  loss_D 0.2157
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/139/index.html
# Epoch 140/150  train  loss_pxl 0.0482  loss_adv 0.3910  loss_D 0.2051
# Epoch 140/150  val  loss_pxl 0.0973  loss_adv 0.3327  loss_D 0.2047
#
# Batch 1/148  loss_pxl 0.0502  loss_adv 0.2930  loss_D 0.2357
# Batch 2/148  loss_pxl 0.0584  loss_adv 0.3732  loss_D 0.1384
# Batch 4/148  loss_pxl 0.0516  loss_adv 0.4765  loss_D 0.1788
# Batch 8/148  loss_pxl 0.0396  loss_adv 0.4194  loss_D 0.2325
# Batch 16/148  loss_pxl 0.0435  loss_adv 0.4235  loss_D 0.2533
# Batch 32/148  loss_pxl 0.0470  loss_adv 0.6380  loss_D 0.2379
# Batch 64/148  loss_pxl 0.0642  loss_adv 0.4396  loss_D 0.1540
# Batch 128/148  loss_pxl 0.0555  loss_adv 0.4142  loss_D 0.2193
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/140/index.html
# Epoch 141/150  train  loss_pxl 0.0484  loss_adv 0.3912  loss_D 0.2095
# Epoch 141/150  val  loss_pxl 0.0973  loss_adv 0.6405  loss_D 0.2382
#
# Batch 1/148  loss_pxl 0.0435  loss_adv 0.5900  loss_D 0.2397
# Batch 2/148  loss_pxl 0.0552  loss_adv 0.3389  loss_D 0.1726
# Batch 4/148  loss_pxl 0.0505  loss_adv 0.3250  loss_D 0.1999
# Batch 8/148  loss_pxl 0.0453  loss_adv 0.3338  loss_D 0.1936
# Batch 16/148  loss_pxl 0.0464  loss_adv 0.4232  loss_D 0.1840
# Batch 32/148  loss_pxl 0.0577  loss_adv 0.4035  loss_D 0.2227
# Batch 64/148  loss_pxl 0.0504  loss_adv 0.6132  loss_D 0.2254
# Batch 128/148  loss_pxl 0.0450  loss_adv 0.2815  loss_D 0.2141
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/141/index.html
# Epoch 142/150  train  loss_pxl 0.0482  loss_adv 0.3939  loss_D 0.2074
# Epoch 142/150  val  loss_pxl 0.0990  loss_adv 0.2446  loss_D 0.1956
#
# Batch 1/148  loss_pxl 0.0544  loss_adv 0.1519  loss_D 0.2594
# Batch 2/148  loss_pxl 0.0469  loss_adv 0.5292  loss_D 0.2093
# Batch 4/148  loss_pxl 0.0432  loss_adv 0.3194  loss_D 0.2291
# Batch 8/148  loss_pxl 0.0430  loss_adv 0.3389  loss_D 0.2234
# Batch 16/148  loss_pxl 0.0459  loss_adv 0.5449  loss_D 0.2024
# Batch 32/148  loss_pxl 0.0436  loss_adv 0.4887  loss_D 0.2577
# Batch 64/148  loss_pxl 0.0350  loss_adv 0.5726  loss_D 0.1808
# Batch 128/148  loss_pxl 0.0626  loss_adv 0.3422  loss_D 0.1496
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/142/index.html
# Epoch 143/150  train  loss_pxl 0.0486  loss_adv 0.3956  loss_D 0.2045
# Epoch 143/150  val  loss_pxl 0.0945  loss_adv 0.6696  loss_D 0.2341
#
# Batch 1/148  loss_pxl 0.0494  loss_adv 0.3763  loss_D 0.2727
# Batch 2/148  loss_pxl 0.0458  loss_adv 0.5221  loss_D 0.2618
# Batch 4/148  loss_pxl 0.0523  loss_adv 0.3538  loss_D 0.2141
# Batch 8/148  loss_pxl 0.0439  loss_adv 0.1956  loss_D 0.2623
# Batch 16/148  loss_pxl 0.0393  loss_adv 0.2508  loss_D 0.2335
# Batch 32/148  loss_pxl 0.0462  loss_adv 0.5669  loss_D 0.2086
# Batch 64/148  loss_pxl 0.0467  loss_adv 0.2791  loss_D 0.2022
# Batch 128/148  loss_pxl 0.0469  loss_adv 0.3330  loss_D 0.2293
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/143/index.html
# Epoch 144/150  train  loss_pxl 0.0483  loss_adv 0.3949  loss_D 0.2050
# Epoch 144/150  val  loss_pxl 0.0988  loss_adv 0.3025  loss_D 0.2024
#
# Batch 1/148  loss_pxl 0.0477  loss_adv 0.2287  loss_D 0.2093
# Batch 2/148  loss_pxl 0.0471  loss_adv 0.3722  loss_D 0.1931
# Batch 4/148  loss_pxl 0.0483  loss_adv 0.2938  loss_D 0.2123
# Batch 8/148  loss_pxl 0.0467  loss_adv 0.3474  loss_D 0.1892
# Batch 16/148  loss_pxl 0.0791  loss_adv 0.3618  loss_D 0.2261
# Batch 32/148  loss_pxl 0.0425  loss_adv 0.5102  loss_D 0.1775
# Batch 64/148  loss_pxl 0.0464  loss_adv 0.3377  loss_D 0.2089
# Batch 128/148  loss_pxl 0.0480  loss_adv 0.2588  loss_D 0.2329
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/144/index.html
# Epoch 145/150  train  loss_pxl 0.0491  loss_adv 0.4009  loss_D 0.2053
# Epoch 145/150  val  loss_pxl 0.0990  loss_adv 0.3630  loss_D 0.1890
#
# Batch 1/148  loss_pxl 0.0396  loss_adv 0.3130  loss_D 0.2044
# Batch 2/148  loss_pxl 0.0455  loss_adv 0.4214  loss_D 0.1802
# Batch 4/148  loss_pxl 0.0420  loss_adv 0.2632  loss_D 0.2225
# Batch 8/148  loss_pxl 0.0465  loss_adv 0.3906  loss_D 0.1659
# Batch 16/148  loss_pxl 0.0416  loss_adv 0.3355  loss_D 0.2261
# Batch 32/148  loss_pxl 0.0581  loss_adv 0.2367  loss_D 0.1994
# Batch 64/148  loss_pxl 0.0491  loss_adv 0.3337  loss_D 0.2006
# Batch 128/148  loss_pxl 0.0532  loss_adv 0.3405  loss_D 0.2026
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/145/index.html
# Epoch 146/150  train  loss_pxl 0.0477  loss_adv 0.3977  loss_D 0.1999
# Epoch 146/150  val  loss_pxl 0.0997  loss_adv 0.5097  loss_D 0.1928
#
# Batch 1/148  loss_pxl 0.0516  loss_adv 0.3995  loss_D 0.2191
# Batch 2/148  loss_pxl 0.0473  loss_adv 0.2801  loss_D 0.2252
# Batch 4/148  loss_pxl 0.0431  loss_adv 0.4225  loss_D 0.2415
# Batch 8/148  loss_pxl 0.0571  loss_adv 0.2794  loss_D 0.1844
# Batch 16/148  loss_pxl 0.0470  loss_adv 0.8425  loss_D 0.2552
# Batch 32/148  loss_pxl 0.0435  loss_adv 0.5736  loss_D 0.2247
# Batch 64/148  loss_pxl 0.0449  loss_adv 0.4961  loss_D 0.1880
# Batch 128/148  loss_pxl 0.0414  loss_adv 0.1854  loss_D 0.2236
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/146/index.html
# Epoch 147/150  train  loss_pxl 0.0484  loss_adv 0.4008  loss_D 0.2098
# Epoch 147/150  val  loss_pxl 0.0964  loss_adv 0.5489  loss_D 0.2050
#
# Batch 1/148  loss_pxl 0.0451  loss_adv 0.4725  loss_D 0.1961
# Batch 2/148  loss_pxl 0.0536  loss_adv 0.4476  loss_D 0.1471
# Batch 4/148  loss_pxl 0.0402  loss_adv 0.4653  loss_D 0.2168
# Batch 8/148  loss_pxl 0.0364  loss_adv 0.4477  loss_D 0.2250
# Batch 16/148  loss_pxl 0.0598  loss_adv 0.2451  loss_D 0.1733
# Batch 32/148  loss_pxl 0.0535  loss_adv 0.4396  loss_D 0.1968
# Batch 64/148  loss_pxl 0.0491  loss_adv 0.1512  loss_D 0.2879
# Batch 128/148  loss_pxl 0.0426  loss_adv 0.2849  loss_D 0.2061
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/147/index.html
# Epoch 148/150  train  loss_pxl 0.0487  loss_adv 0.3984  loss_D 0.2030
# Epoch 148/150  val  loss_pxl 0.0988  loss_adv 0.4278  loss_D 0.1866
#
# Batch 1/148  loss_pxl 0.0527  loss_adv 0.3243  loss_D 0.2225
# Batch 2/148  loss_pxl 0.0449  loss_adv 0.3314  loss_D 0.1898
# Batch 4/148  loss_pxl 0.0689  loss_adv 0.6363  loss_D 0.1467
# Batch 8/148  loss_pxl 0.0457  loss_adv 0.3604  loss_D 0.1954
# Batch 16/148  loss_pxl 0.0665  loss_adv 0.2768  loss_D 0.1940
# Batch 32/148  loss_pxl 0.0501  loss_adv 0.2802  loss_D 0.2381
# Batch 64/148  loss_pxl 0.0492  loss_adv 0.5808  loss_D 0.2108
# Batch 128/148  loss_pxl 0.0528  loss_adv 0.5570  loss_D 0.1992
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/148/index.html
# Epoch 149/150  train  loss_pxl 0.0488  loss_adv 0.3991  loss_D 0.2036
# Epoch 149/150  val  loss_pxl 0.0978  loss_adv 0.7135  loss_D 0.2668
#
# Batch 1/148  loss_pxl 0.0555  loss_adv 0.7113  loss_D 0.2202
# Batch 2/148  loss_pxl 0.0441  loss_adv 0.3544  loss_D 0.2229
# Batch 4/148  loss_pxl 0.0471  loss_adv 0.3716  loss_D 0.2154
# Batch 8/148  loss_pxl 0.0551  loss_adv 0.4829  loss_D 0.1523
# Batch 16/148  loss_pxl 0.0535  loss_adv 0.2038  loss_D 0.2230
# Batch 32/148  loss_pxl 0.0523  loss_adv 0.4548  loss_D 0.1816
# Batch 64/148  loss_pxl 0.0507  loss_adv 0.5493  loss_D 0.2047
# Batch 128/148  loss_pxl 0.0536  loss_adv 0.7325  loss_D 0.1926
# Generated image table at: /content/drive/MyDrive/Image Outpainting and Harmonization using GANs - PyTorch Implementation/outpaint_html/149/index.html
# Epoch 150/150  train  loss_pxl 0.0476  loss_adv 0.4033  loss_D 0.2056
# Epoch 150/150  val  loss_pxl 0.0942  loss_adv 0.4970  loss_D 0.2344
#
# Done!
